# %% [markdown]
# # installing libraries

# %%
import sys
print(sys.executable)

import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip uninstall -y newspaper3k newspaper
# !{sys.executable} -m pip install newspaper3k
# !{sys.executable} -m pip install lxml-html-clean
# !{sys.executable} -m pip install pymongo

# %% [markdown]
# # 🧠 InBrief: Tech
#
# This notebook automates a pipeline that:
#
# 1. ⏬ Fetches the latest **technology-related news articles**
# 2. ✂️ Summarizes each article using **Google's Gemini (Generative AI)**
# 3. 🧮 Scores each article based on **relevance, impact, sentiment, and novelty**
# 4. 🗃 Stores raw articles, summaries, and scores into separate **MongoDB collections**
#
# *use your own api key

# %%
import requests
from datetime import date,timedelta
from newspaper import Article
import json
from pymongo import MongoClient
from google import genai
from google.genai import types
from pydantic import BaseModel

# Utility function to generate a date range string for the News API
def get_date_range(No_of_days):
    current_date = date.today()
    two_days_ago = current_date - timedelta(days=No_of_days)
    current_date = str(current_date)
    two_days_ago = str(two_days_ago)
    date_string = "from=" + two_days_ago + "&to=" + current_date
    return date_string

# Fetches technology news articles from the News API and parses their full text
def get_articles(date_range):
    L = []
    url = "https://newsapi.org/v2/everything?q=technology&"+date_range+"&language=en&sortBy=relevancy"
    headers = {"Authorization": "API_KEY",
    "Content-Type": "application/json"}
    response = requests.get(url,headers = headers)
    data = response.json()
    L = []
    for j in data['articles']:
        url = j['url']
        try:
            article = Article(url)
            article.download()
            article.parse()
            art = {
                'title' : j['title'],
                'text'  : article.text
            }
            L.append(art)
        except Exception as e:
            # Silently skip failed articles
            pass

    # Return both the string and original list format
    art_str = json.dumps(L)
    return art_str,L

# Uses Gemini (via Google GenAI) to summarize articles and extract key metadata
def summarization(input_string):

    # Schema definition for expected structured response
    class Recipe(BaseModel):
        title: str
        summary: str
        keyword: list[str]
        topic: str
        entities: list[str]
        sentiment: str

    client = genai.Client(api_key="API_KEY")

    # Instruction prompt for the GenAI model
    system_instruction='''generate the output stricly in json 

instructions:
-remove the word json at the start, the triple quotes(most importantly)
-remove any newline elements in the output string
-format the json in a way it could be successfully parsed and given as input to json.load()
-I have provided a list containing dictionaries of multiple articles,each provinding the id, title and text of a particular article.
-summarize the text given in a few sentences
-add a key 'title' and add value x['title'] to it.
-add a key 'summary' which contains the summarised text including all the vital points
-add a key 'keyword' which includes all significant keywords and terms related to the relavant technology and trends
-add a key 'topic' which includes the catergory the news belong to.
-add a key 'entities' which includes a list of important entities involved in the technology, for example-organization,people,location.
-add a key 'sentiment' which includes sentiments as positive, negative or nuetral.
'''
    
    # Make the actual call to Gemini
    response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[input_string,system_instruction],
    config={
        "response_mime_type": "application/json",
        "response_schema": list[Recipe],
    },
)
    return response.text

# Uses Gemini to assign a relevancy score to each article based on multiple dimensions
def relevancy_score(input_string):
    class Recipe(BaseModel):
        title: str
        summary: str
        keyword: list[str]
        topic: str
        entities: list[str]
        sentiment: str
        relevancy_score:str # Additional score field

    client = genai.Client(api_key="API_KEY")
    system_instruction='''generate the output stricly in json 

instructions:
-remove the word json at the start, the triple quotes(most importantly)
-remove any newline elements in the output string
-format the json in a way it could be successfully parsed and given as input to json.load()
-I have provided a json string including fields such as topic,summary,keyword,entities and sentiment.
-add an extra field 'relevancy_score' to rank each acticles on the basis of criteria such as impact, novelty, most relevant and important technology,
sentiments,etc. after analyzing all the fields provided.
'''
    response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[input_string,system_instruction],
    config={
        "response_mime_type": "application/json",
        "response_schema": list[Recipe],
    },
)

    return response.text


#getting news info from news api

date_range = get_date_range(2)
articles_string, articles_list  = get_articles(date_range)

#Creating a database named tech_news_db to save text and title generated from the newsapi

client = MongoClient("mongodb://localhost:27017/")
db = client["tech_news_db"]
collection = db["articles"]
result = collection.insert_many(articles_list)

#summarizing the text of each news article

summary_index = summarization(articles_string)
list_of_summarized_articles = json.loads(summary_index)


#database to store the summary,title,keyword....
client = MongoClient()
new_database = client['new_database']
new_collection = new_database['articles']
y = new_collection.insert_many(list_of_summarized_articles)

#getting relevancy score data


relevancy_score_data = relevancy_score(summary_index)
print(relevancy_score)
list_of_relevant_articles = json.loads(relevancy_score_data)

# 📚 Store final articles with relevancy score into DB

Client_2 = MongoClient()
news_articles_info = Client_2['news_article_info']
news_collection = news_articles_info['news_collection']
result = news_collection.insert_many(list_of_relevant_articles)
# Out:
# c:\Users\Anusha\AppData\Local\Programs\Python\Python312\Lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# [
#   {
#     "title": "UK Scientists Achieve First Commercial Tritium Production",
#     "summary": "UK scientists, led by Professor Tom Scott from the University of Bristol, have successfully achieved the first commercial production of tritium, a crucial step towards scalable nuclear fusion energy. This breakthrough demonstrates the potential of Multi-State Fusion for isotope production, with nuclear fusion offering an energy output four times higher than fission.",
#     "keyword": ["Tritium production", "nuclear fusion", "isotopes", "Multi-State Fusion", "energy output", "commercial production"],
#     "topic": "Science & Technology",
#     "entities": ["University of Bristol", "Royal Academy of Engineering", "UK Atomic Energy Authority", "Tom Scott", "International Atomic Energy Agency", "The Cooldown"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "XBOW's AI-Powered Pentester Grabs Top Rank on HackerOne, Raises $75M to Grow Platform",
#     "summary": "XBOW's AI-powered penetration tester has achieved the top rank on HackerOne's US security industry leaderboard, leading to the company raising $75 million in Series B funding, bringing its total to $117 million. This development highlights the increasing use of AI in cybersecurity for both offense and defense.",
#     "keyword": ["AI-powered pentester", "penetration testing", "cybersecurity", "HackerOne", "Series B funding", "AI automation"],
#     "topic": "Artificial Intelligence",
#     "entities": ["XBOW", "HackerOne", "CSO Online", "Help Net Security"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "This Weird Pyramid Always Lands on the Same Face, Confirming 40-Year-Old Theory",
#     "summary": "Scientists have created \"Bille,\" the first monostable tetrahedron, a pyramid-like shape that consistently lands on the same face, confirming a 40-year-old theory by mathematician John Conway. Made of carbon fiber and tungsten carbide, this technological and mathematical achievement has potential applications for the spaceflight industry, particularly for self-righting lunar landers, and builds upon prior work on similar balancing objects like the gömböc.",
#     "keyword": ["Monostable tetrahedron", "Bille", "John Conway", "self-righting", "spaceflight", "lunar landers", "gömböc", "geometry", "engineering", "mathematical theory"],
#     "topic": "Science & Technology",
#     "entities": ["Bille", "John Conway", "Robert Dawson", "Gábor Domokos", "Gergő Almádi", "Saint Mary's University", "Budapest University of Technology and Economics", "Gizmodo", "Novo Nordisk", "MIT", "Harvard", "arXiv"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "I toured Morgan Stanley's Innovation Lab and saw firsthand how banks are trying to pull top tech talent",
#     "summary": "Morgan Stanley's Innovation Lab in Manhattan's Financial District is a large data center designed to test tech ideas and products, aiming to attract and retain top technologists. The bank uses incentives like a Patent Accelerator Program and public recognition for patent holders to compete with tech companies for talent, reflecting a broader trend of banks increasing tech spending and in-house development.",
#     "keyword": ["Innovation Lab", "financial technology", "tech talent", "patents", "banking", "data center", "financial industry", "technology spending", "corporate innovation"],
#     "topic": "Business & Finance",
#     "entities": ["Morgan Stanley", "Megan Brewer", "Business Insider", "McKinsey", "Citi"],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "Here's Why Cars Stopped Using Solid Lifters",
#     "summary": "Carmakers have largely moved away from solid lifters in engines due to their high maintenance requirements, such as frequent valve adjustments caused by thermal expansion and wear. Hydraulic lifters, despite being heavier and more complex, offer maintenance-free operation by using oil pressure to compensate for thermal expansion, making them preferable for modern vehicles where long-term, low-maintenance parts are highly valued.",
#     "keyword": ["Solid lifters", "hydraulic lifters", "engine technology", "valve adjustment", "thermal expansion", "lubrication", "car maintenance", "automotive engineering"],
#     "topic": "Automotive",
#     "entities": ["Mercedes"],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "Nuclear Microreactors Advance as US Picks Two Companies for Fueled Testing",
#     "summary": "The US Energy Department has selected two companies for the first fueled nuclear microreactor tests at its new DOME facility in Idaho, with tests starting as early as spring 2026. This initiative aims to accelerate the commercialization of advanced microreactors, which could produce up to 20 megawatts of thermal energy and lead to mass production of portable reactors, boosting American nuclear energy dominance.",
#     "keyword": ["Nuclear microreactors", "fueled testing", "DOME facility", "thermal energy", "portable reactors", "nuclear energy", "commercialization"],
#     "topic": "Energy",
#     "entities": ["US Energy Department", "DOME", "Interesting Engineering", "Radiant"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Pixar's chief creative officer says AI is 'the least impressive blah average of things'",
#     "summary": "Pete Docter, Pixar's chief creative officer, expressed unimpressed views on AI, calling it \"bland\" and \"the least impressive blah average of things,\" despite ongoing industry anxiety about AI's impact on animation jobs. While acknowledging AI could ease cumbersome tasks, he believes it won't replace human creativity, similar to how computers made animation more accessible without eliminating animators.",
#     "keyword": ["AI in animation", "Pixar", "Pete Docter", "creative industry", "job displacement", "filmmaking process", "AI tools", "human creativity"],
#     "topic": "Artificial Intelligence",
#     "entities": ["Pixar", "Pete Docter", "Mike Birbiglia", "James Cameron", "Disney", "Business Insider"],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "Meet the Robot Side Table Concept That Blends Human Touch With Modern Living",
#     "summary": "The Bable Robot Side Table concept introduces a subtle, integrated approach to home robotics, blending technology seamlessly into daily life rather than drawing attention. Designed with warmth and charm, this side table features invisible technology, such as a downward-facing ring light for gentle illumination and a built-in drawer, aiming to be a caring companion that supports routines without interruption.",
#     "keyword": ["Robot side table", "home robotics", "invisible technology", "ambient illumination", "smart furniture", "product design", "human-robot interaction", "concept design"],
#     "topic": "Robotics",
#     "entities": ["Bable Robot Side Table", "Abin Rajendran"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "What is digital art? Everything you need to know",
#     "summary": "Digital art is broadly defined as art created using electronic tools and systems, encompassing various forms from 2D pixel art to 3D CGI and algorithmic art. While the lines between traditional and digital art are blurring, digital art offers benefits like cost-effectiveness, flexibility in editing, easier storage, and wider sharing, with future trends including Web 3.0, VR/AR experiences, NFTs, and AI integration.",
#     "keyword": ["Digital art", "electronic tools", "CGI", "pixel art", "algorithmic art", "NFTs", "AI art", "VR/AR", "art software", "drawing tablets", "traditional art"],
#     "topic": "Art",
#     "entities": ["David Hockney", "Takashi Murakami", "Damien Hirst", "Rachel Whiteread", "Allan Kaprow", "Ivan Sutherland", "Frieder Nake", "Harold Cohen", "Quantel Paintbox", "Photoshop", "Procreate", "Blender", "Ed Atkins", "Pixel Jeff", "Adobe Illustrator", "Rebelle"],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "Robinhood Wants to Redo Wall Street on the Blockchain",
#     "summary": "Robinhood is unveiling a new vision to revolutionize finance by moving traditional financial assets like stocks, ETFs, and derivatives onto the blockchain, starting with stock tokens for European customers on Arbitrum. The company is building its own Layer 2 blockchain to support tokenization, 24/7 trading, self-custody, and eliminate financial middlemen, alongside introducing crypto perpetual futures and staking, aiming to fundamentally reshape the global financial system.",
#     "keyword": ["Blockchain", "Wall Street", "stock tokens", "ETFs", "derivatives", "cryptocurrency", "Layer 2 blockchain", "Arbitrum", "Ethereum", "self-custody", "staking", "smart routing", "AI-powered investing", "financial system", "tokenization"],
#     "topic": "Finance",
#     "entities": ["Robinhood", "Arbitrum", "Ethereum", "Vlad Tenev", "OpenAI", "SpaceX", "Cortex"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Thanks to Trump, the clean energy industry is in jeopardy",
#     "summary": "The American clean energy industry, which thrived under the Biden-Harris administration, faces significant jeopardy due to President Donald Trump's \"One Big Beautiful Bill Act.\" This legislation eliminates key tax credits for residential solar, utility-scale solar and wind, EVs, and other clean energy technologies, threatening industry growth, job creation, and potentially increasing consumer energy prices. Critics argue Trump's policies prioritize fossil fuels despite a growing national demand for energy, potentially hindering the transition to clean energy.",
#     "keyword": ["Clean energy", "tax credits", "renewable energy", "solar power", "wind power", "electric vehicles", "energy storage", "fossil fuels", "climate crisis", "energy policy", "economic impact", "legislation"],
#     "topic": "Politics",
#     "entities": ["Donald Trump", "Biden-Harris administration", "Joe Biden", "Inflation Reduction Act", "Infrastructure Investment and Jobs Act", "American Clean Power Association", "U.S. Department of Energy", "Dr. Daniel Kammen", "University of California at Berkeley", "Elon Musk", "xAI Colossus", "Jason Grumet"],
#     "sentiment": "negative"
#   },
#   {
#     "title": "At China’s robot school, machines learn like humans, teacher uses VR headset",
#     "summary": "China has established a robot school where robots learn various work scenarios, such as logistics, part handling, and customer service, through intensive real-world physical data input from human trainers using VR headsets. This unique training method exposes robots to unpredictable situations, enhancing their ability to adapt and generalize across environments, aiming for autonomous task performance beyond simple memorization.",
#     "keyword": ["Robot training", "machine learning", "AI", "VR headset", "real-world data", "autonomous robots", "robotics education", "logistics", "customer service"],
#     "topic": "Robotics",
#     "entities": ["China"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Ukraine's ground drones work like Lego, with soldiers putting parts together to perform different missions",
#     "summary": "Ukrainian soldiers are utilizing ground robots with a \"Lego-like\" modular design, allowing them to reconfigure the drones for various missions, from evacuating wounded soldiers to kamikaze attacks. This adaptability, highlighted by companies like FRDM Group and Milrem Robotics, enables rapid innovation on the battlefield, where soldiers provide direct feedback to manufacturers for continuous updates, reflecting a new reality of fast-paced technological adaptation in warfare.",
#     "keyword": ["Ground drones", "modular design", "military robotics", "battlefield innovation", "adaptable systems", "kamikaze drones", "soldier feedback", "D-21", "THeMIS", "warfare technology"],
#     "topic": "Military Technology",
#     "entities": ["Ukraine", "Oleksandr Yabchanka", "Da Vinci Wolves Battalion", "FRDM Group", "Vadym Yunyk", "Mykhailo Fedorov", "Milrem Robotics", "Estonia", "Kuldar Vääärsi", "Russia"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "New tech tracks blood sodium without a single needle",
#     "summary": "Researchers have developed a new non-invasive technology that combines optoacoustic detection with terahertz spectroscopy to monitor blood sodium levels without needles. This method overcomes challenges of water absorption in biological samples, enabling real-time detection of sodium ions and potentially other biomolecules. Successful preliminary tests in mice and human volunteers suggest a future where this technology could revolutionize diagnostics and patient management by providing continuous, safe monitoring of critical health markers.",
#     "keyword": ["Non-invasive monitoring", "blood sodium", "optoacoustic detection", "terahertz spectroscopy", "biomedical applications", "biomolecules", "medical technology", "diagnostic tools", "real-time monitoring"],
#     "topic": "Medical Technology",
#     "entities": ["Zhen Tian", "Tianjin University", "Optica Publishing Group", "Optica"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "A conservative crackdown on advertisers has forced a 'brand safety' reset",
#     "summary": "A conservative backlash, fueled by the Trump administration's return and led by entities like The Daily Wire and FTC Chairman Andrew Ferguson, is forcing a \"brand safety\" reset in the advertising industry. Previously, \"brand safety\" often led to boycotts of politically conservative media, but new legal actions and FTC oversight are pushing advertisers towards \"brand suitability\" and more politically neutral ad placements. This shift challenges established ad practices and could benefit news publishers, while also raising concerns about government overreach and the consolidation of power with tech giants.",
#     "keyword": ["Brand safety", "brand suitability", "advertising", "conservative media", "ad agencies", "FTC", "political bias", "ad tech", "digital advertising", "censorship", "market shift", "antitrust"],
#     "topic": "Media",
#     "entities": ["The Daily Wire", "Omnicom", "Ben Shapiro", "Brent Scher", "Donald Trump", "Andrew Ferguson", "FTC", "IPG", "Liam Brennan", "Mark Penn", "Stagwell", "Mike Zaneis", "Trustworthy Accountability Group", "Ariana Grande", "Jim Jordan", "House Judiciary Committee", "Global Alliance for Responsible Media", "X", "Elon Musk", "Mars", "CVS Health", "Rumble", "World Federation of Advertisers", "Media Matters", "Ad Fontes Media", "Integral Ad Science", "DoubleVerify", "Symitri", "David Kohl", "Mobian", "The Trade Desk", "Public Knowledge", "Lisa Macpherson", "Dentsu", "Alphabet", "Meta", "Amazon", "WARC"],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "Edible Microlasers Could Revolutionize Food Tracking and Safety",
#     "summary": "Scientists have developed the first edible microlasers using olive oil, which exploits chlorophyll's light-emitting properties. These lasers are highly sensitive to environmental conditions like sugar concentration or acidity and can encode data similar to barcodes, with data remaining intact for over a year in food like peach compote. This breakthrough holds significant potential for revolutionizing food tracking, safety monitoring, and medication delivery from within the body.",
#     "keyword": ["Edible microlasers", "food tracking", "food safety", "chlorophyll", "olive oil", "optical technology", "data encoding", "medication delivery", "sensing", "biomedical applications"],
#     "topic": "Science & Technology",
#     "entities": [],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Netflix explains how it's quietly upgraded the image quality of your favorite movies and TV shows –and it's all about film grain",
#     "summary": "Netflix has implemented a new technology called \"AV1 Film Grain Synthesis\" (FGS) since March 2025 to enhance the image quality of its movies and TV shows by recreating realistic film grain, which is often lost during compression. This clever technique analyzes original video for grain patterns and reconstructs them on the viewer's device, not only improving the \"movie look\" but also significantly reducing bitrate, network bandwidth, playback errors, and start-up delay for a more stable streaming experience.",
#     "keyword": ["Netflix", "AV1 Film Grain Synthesis", "FGS", "image quality", "film grain", "streaming technology", "video compression", "bitrate", "network bandwidth", "playback performance"],
#     "topic": "Entertainment",
#     "entities": ["Netflix", "Techblog"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "adidas Gave the Samba the Boot",
#     "summary": "Adidas has released a unique new version of its classic Samba soccer shoe, transforming it into a calf-high boot with a removable shaft. This design also features navy blue reptilian textures and buttery leather accents, offering a luxurious and versatile option that can be worn as a boot or converted back to a low-top sneaker.",
#     "keyword": ["Adidas", "Samba", "soccer shoe", "calf-high boot", "removable shaft", "reptilian texture", "sneaker design", "footwear", "fashion", "product innovation"],
#     "topic": "Fashion",
#     "entities": ["Adidas", "Wales Bonner", "Highsnobiety"],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "Do You Really Learn When You Use AI? What MIT Researchers Found",
#     "summary": "An MIT study suggests that using generative AI tools like ChatGPT for tasks, such as essay writing, leads to weaker memory traces, reduced self-monitoring, and fragmented authorship compared to working independently. While AI can ease cognitive load, the preliminary research indicates that heavy reliance on AI may hinder knowledge internalization and a sense of ownership, supporting an educational model that delays AI integration until foundational cognitive effort is established.",
#     "keyword": ["Generative AI", "ChatGPT", "learning", "memory", "cognitive load", "essay writing", "neural connectivity", "self-monitoring", "authorship", "education", "AI ethics", "human cognition"],
#     "topic": "Artificial Intelligence",
#     "entities": ["MIT", "OpenAI", "ChatGPT", "Nataliya Kosmyna", "Ziff Davis", "CNET", "The Washington Post", "Genevieve Stein-O'Brien", "Johns Hopkins University", "Robert Cummings", "University of Mississippi"],
#     "sentiment": "negative"
#   },
#   {
#     "title": "Tiny twitches, big breakthrough: New clues to catch Parkinson’s sooner",
#     "summary": "Researchers have discovered that subtle motor behaviors like rearing and hunching are key biomarkers for the loss of midbrain dopamine neurons in the substantia nigra pars compacta (SNc), a hallmark of Parkinson's disease (PD). Using machine learning-enhanced 3D analysis in mouse models, this study highlights these \"tiny twitches\" as potential indicators for earlier PD detection and better treatment strategies, distinguishing SNc neuron loss from VTA neuron effects.",
#     "keyword": ["Parkinson's disease", "dopamine neurons", "SNc", "VTA", "behavioral biomarkers", "machine learning", "3D analysis", "motor behaviors", "neurodegenerative disease", "early detection"],
#     "topic": "Medical Research",
#     "entities": ["Xuemei Liu", "Pengfei Wei", "Shenzhen Institutes of Advanced Technology", "Chinese Academy of Sciences", "Translational Psychiatry"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Operators, Not Users and Programmers",
#     "summary": "The article advocates for a future computing model where the distinction between \"users\" and \"programmers\" disappears, replaced by \"operators\" who can easily manipulate software. Drawing inspiration from the success of spreadsheets and WYSIWYG editors, the author envisions \"malleable systems\" that offer hot-reloading, live previews, continuous durability with full undo/redo, distributed version control, automatic testing, and continuous deployment, making programming as accessible as writing a resume.",
#     "keyword": ["Malleable software", "operators", "user experience", "programming", "spreadsheets", "WYSIWYG editors", "version control", "continuous integration", "continuous deployment", "hot-patching", "live previews", "software design"],
#     "topic": "Software Engineering",
#     "entities": ["Felienne Hermans", "Rik", "Stanislav", "Brian M. Kelly", "Cal Peterson", "Microsoft Word", "Obsidian", "Typst", "Wordpress", "Google Drive", "Sharepoint", "Onedrive", "Piper", "jj", "Excel"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Paralyzed rats walk again, thanks to breakthrough spinal cord implants",
#     "summary": "Researchers in New Zealand have developed a minimally invasive spinal cord implant that uses low-frequency electric field treatment to stimulate nerve regeneration, enabling paralyzed rats to regain hind limb function and sensation. This breakthrough, distinct from previous methods, shows significant promise for treating human spinal cord injuries, despite rats having a higher capacity for natural recovery.",
#     "keyword": ["Spinal cord injury", "nerve regeneration", "electric field treatment", "implant technology", "paralysis", "neuro-rehabilitation", "medical device", "animal model", "minimally invasive"],
#     "topic": "Medical Research",
#     "entities": ["University of Auckland", "Darren Svirskis", "Chalmers University of Technology", "Nature Communications"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Welcome to Silicon Valley's winner-take-all era",
#     "summary": "Silicon Valley is entering a \"winner-take-all era\" driven by the intense competition for top AI talent, with companies like Meta reportedly offering exorbitant pay packages of up to $300 million to AI researchers. This creates a vast pay disparity and resentment among other tech workers, while thousands face layoffs. Experts debate whether these \"superstar athlete\" salaries are a temporary phenomenon or a long-term shift, reflecting high stakes in the AI market and pressure to cut costs elsewhere.",
#     "keyword": ["Silicon Valley", "AI talent", "compensation", "tech layoffs", "pay disparity", "artificial intelligence", "economic sociology", "corporate strategy", "tech industry"],
#     "topic": "Technology",
#     "entities": ["Meta", "OpenAI", "Wired", "Sam Altman", "Andy Stone", "Business Insider", "Natalia Luka", "University of California, Berkeley", "Microsoft", "Xbox", "Layoffs.fyi", "Scale AI", "Google", "Tim Herbert", "CompTIA", "Blind", "Sonny Tambe", "Wharton School of the University of Pennsylvania"],
#     "sentiment": "negative"
#   },
#   {
#     "title": "It's illegal in most states for private equity to buy a law firm. Lawyers have figured out a workaround.",
#     "summary": "While most US states prohibit non-lawyer ownership of law firms, lawyers are circumventing this rule using \"managed services organizations\" (MSOs). This workaround allows private equity firms to invest in a separate entity that handles non-legal operations (like marketing, HR, accounting) for the law firm, providing a path for lawyers to retire or scale their practices while maintaining ethical independence. This model is gaining traction, especially for consumer-driven firms.",
#     "keyword": ["Private equity", "law firms", "legal ethics", "managed services organization", "MSO", "non-lawyer ownership", "legal industry", "mergers and acquisitions", "business model", "regulatory compliance"],
#     "topic": "Law",
#     "entities": ["American Bar Association", "Puerto Rico", "Arizona", "Stanford Law School", "KPMG", "Rocket Lawyer", "Lucian Pera", "Adams & Reese", "Tom Lenfestey", "The Law Market Exchange", "Catalex Network", "Jeffrey Goldenhersh", "Skadden Arps", "Jesse Hamilton", "Business Insider"],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "Early Prime Day Deals on Electric Toothbrushes and Tooth Whiteners",
#     "summary": "Amazon is offering early Prime Day 2025 deals on electric toothbrushes and tooth whiteners, allowing consumers to achieve a \"picture perfect smile.\" Featured products include Philips Sonicare electric toothbrushes with advanced features like pressure sensors and high movements per minute, Crest 3D Whitestrips with LED accelerator lights, and Oral-B electric toothbrushes with smart displays and AI brushing recognition, alongside a Waterpik Cordless Advanced 2.0 Water Flosser.",
#     "keyword": ["Prime Day", "electric toothbrush", "tooth whitener", "water flosser", "oral hygiene", "smart toothbrush", "AI brushing recognition", "consumer electronics", "sales", "dental care"],
#     "topic": "Consumer Products",
#     "entities": ["Amazon", "TMZ", "Scarlett Johansson", "Priyanka Chopra", "Charlize Theron", "Philips Sonicare", "Crest 3D Whitestrips", "Oral-B", "Waterpik"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Lamps transform ocean plastic into artful home decor",
#     "summary": "Xuanhao Li's \"Polycycle Illumination\" collection transforms discarded ocean plastic film, particularly transparent HDPE from the textile industry, into artful, jellyfish-inspired table lamps. Utilizing parametric design, CNC cutting, and hand assembly, these lamps not only provide illumination but also advocate against plastic pollution, offering a sustainable solution for upcycling hard-to-recycle materials and raising environmental awareness.",
#     "keyword": ["Ocean plastic", "plastic pollution", "upcycling", "sustainable design", "home decor", "table lamps", "parametric design", "CNC cutting", "environmental advocacy", "recycled materials", "artful design"],
#     "topic": "Environmental",
#     "entities": ["Xuanhao Li", "Polycycle Illumination"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "In Texas region prone to catastrophic floods, questions grow about lack of warning",
#     "summary": "The provided article text is incomplete, consisting only of a reCAPTCHA message. Therefore, a summary of the content regarding floods and warnings in Texas cannot be generated.",
#     "keyword": ["Incomplete article", "information unavailable"],
#     "topic": "Information Unavailable",
#     "entities": [],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "19% of food and drink from biggest US brands contain controversial dyes",
#     "summary": "A comprehensive study revealed that nearly 20% of packaged foods and drinks from the 25 biggest US brands contain synthetic food dyes, with some categories like confectionery and sports drinks showing higher prevalence. These products also contain significantly more added sugar. Despite health concerns and mounting pressure, including potential state-level bans and FDA requests, many companies are only beginning to phase out these dyes, highlighting the ongoing debate between consumer health, industry profits, and regulatory action.",
#     "keyword": ["Synthetic food dyes", "food additives", "processed foods", "public health", "neurobehavioral issues", "Red 3", "Red 40", "Yellow 5", "Blue 1", "Blue 2", "Green 3", "FDA", "European Union", "consumer awareness", "sugar content", "food regulation"],
#     "topic": "Health",
#     "entities": ["The George Institute for Global Health", "University of North Carolina", "Center for Science in the Public Interest", "Ferrero", "Mars", "PepsiCo", "Nestlé USA", "Kraft Heinz", "Conagra Brands", "General Mills", "US Food and Drug Administration", "International Association of Color Manufacturers", "Office of Environmental Health Hazard Assessment", "Journal of the Academy of Nutrition and Dietetics", "Dr Elizabeth Dunford", "Dr Thomas Galligan"],
#     "sentiment": "negative"
#   },
#   {
#     "title": "MTG Wants to Make ‘Deadly’ Weather Manipulation a Felony",
#     "summary": "Republican Congresswoman Marjorie Taylor Greene plans to introduce a bill making \"climate modification\" or \"geoengineering\" a felony, prohibiting the release of chemicals into the atmosphere to alter weather or climate. Greene, a vocal proponent of controversial theories regarding weather control, claims to have researched the topic extensively and believes such practices are \"dangerous and deadly,\" despite expert community notes refuting her claims about artificial storm creation.",
#     "keyword": ["Climate modification", "geoengineering", "weather manipulation", "Marjorie Taylor Greene", "felony", "conspiracy theories", "climate policy", "legislative action", "misinformation"],
#     "topic": "Politics",
#     "entities": ["Marjorie Taylor Greene", "Donald Trump", "Florida Senate", "X"],
#     "sentiment": "negative"
#   },
#   {
#     "title": "This Week’s Awesome Tech Stories From Around the Web (Through July 5)",
#     "summary": "This compilation features several \"awesome tech stories,\" including the exponential improvement of large language models (LLMs) with capabilities doubling every seven months, Amazon's increasing reliance on robots in warehouses (approaching human workforce numbers), experimental gene therapy restoring hearing in older deaf patients, the discovery of a third interstellar comet, and the emergence of AI-generated music bands on platforms like Spotify. Superwood, a bulletproof and fire-resistant material, is also highlighted.",
#     "keyword": ["Large language models", "LLMs", "AI capabilities", "robotics", "Amazon warehouses", "gene therapy", "hearing loss", "interstellar comet", "AI-generated music", "Superwood", "material science", "tech news"],
#     "topic": "Technology (General)",
#     "entities": ["Glenn Zorpette", "IEEE Spectrum", "Sebastian Herrera", "The Wall Street Journal", "Amazon", "Ellyn Lapointe", "Gizmodo", "Kenneth Chang", "The New York Times", "3I/ATLAS", "Dr. Chodas", "Ryan Whitwam", "Ars Technica", "Spotify", "The Velvet Sundown", "Christopher Mims", "InventWood"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "For 100 years, we have marveled at planetariums. Here's a brief history of how humans brought the stars indoors",
#     "summary": "Marking 100 years since the first opto-mechanical planetarium debuted in Munich in 1925, the article traces the history of bringing celestial views indoors, from ancient orreries to modern digital fulldome theaters. Prompted by light pollution, these inventions, pioneered by Carl Zeiss AG, evolved to project realistic starfields and allow virtual space travel. Planetariums continue to inspire wonder, integrating data from global telescopes and serving as gateways to understanding the vast universe.",
#     "keyword": ["Planetarium", "opto-mechanical planetarium", "orrery", "digital planetarium", "fulldome", "astronomy", "light pollution", "Carl Zeiss AG", "space visualization", "scientific display", "educational technology", "history of science"],
#     "topic": "Science & Technology",
#     "entities": ["Deutsches Museum", "Oskar von Miller", "Carl Zeiss AG", "Atwood Sphere", "Manitoba Museum Planetarium", "Jennifer Chalsty Planetarium", "Adler Planetarium", "Edwin Hubble", "Melbourne Planetarium", "Museums Victoria", "Stardome Observatory", "Evans and Sutherland"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Hilarious Take on 21st-Century Society Through These Witty Comics By Luke McGarry (17 Pics)",
#     "summary": "The article introduces a collection of witty comics by Luke McGarry that offer a \"hilarious take\" on 21st-century society. It highlights how technology allows for easy access to \"mildly interesting\" content, reflecting a modern continuum of interest.",
#     "keyword": ["Comics", "social commentary", "wit", "21st-century society", "technology", "humor", "digital content", "art"],
#     "topic": "Art",
#     "entities": ["Luke McGarry", "Greta Jaruševi\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ...
#     "summary: \"Veeva, a dominant cloud software provider for life sciences, achieved $100M ARR with only $3M raised by adopting an \"ultra-vertical\" strategy focused on the pharmaceutical industry. Founder Peter Gassner's contrarian approach, combined with extreme capital discipline, profitable professional services, premium pricing, and strategic multi-product expansion only into larger markets, allowed Veeva to build a highly successful and profitable business with high switching costs and deep customer relationships, eventually becoming a $45.9B market cap company.",
#     "keyword: [\"SaaS\", \"vertical SaaS\", \"cloud software\", \"life sciences\", \"pharmaceutical industry\", \"capital discipline\", \"profitability\", \"premium pricing\", \"customer relationships\", \"multi-product strategy\", \"B2B software\", \"enterprise software\", \"business growth\"],",
#     "topic: \"Business & Finance\",",
#     "entities: [\"Veeva\", \"Peter Gassner\", \"Salesforce\", \"IBM\", \"PeopleSoft\", \"Emergence Capital\", \"Vault\", \"Amazon\", \"SaaStr\"],",
#     "sentiment: \"positive\""
#   ]
#   ,
#   "sentiment": "positive"
# },
# {
#   "title": "Foldable iPad Plans Temporarily Shelved",
#   "summary": "Apple has reportedly paused its plans for a foldable iPad, or \"all-display MacBook,\" due to low consumer demand, high costs of foldable display components, and manufacturing difficulties. Rumored to be between 18.8 to 20.2 inches with a crease-free OLED display, the product's development might resume when display technology becomes more affordable and market demand increases, with Apple's current focus shifting to a foldable iPhone, possibly debuting in 2026.",
#   "keyword": ["Foldable iPad", "foldable MacBook", "Apple", "OLED display", "foldable technology", "consumer demand", "manufacturing costs", "product development", "iPhone 18 Pro", "consumer electronics"],
#   "topic": "Consumer Electronics",
#   "entities": ["Apple", "DigiTimes", "iPhone 18 Pro"],
#   "sentiment": "negative"
# },
# {
#   "title": "Electric & Hybrid Vehicle Technology International - June 2025",
#   "summary": "\"Electric & Hybrid Vehicle Technology International - June 2025\" is presented as the world's leading international showcase for technology and innovation in electric, hybrid, and fuel-cell vehicle development and manufacture. The entry is a magazine listing, indicating its focus on advanced automotive technologies.",
#   "keyword": ["Electric vehicles", "EV", "hybrid vehicles", "fuel-cell vehicles", "automotive technology", "innovation", "manufacturing", "magazine", "transportation"],
#   "topic": "Automotive",
#   "entities": ["OMEGA", "Tornado"],
#   "sentiment": "neutral"
# },
# {
#   "title": "This surprisingly simple way to hide hardware security keys in mainstream flash memory could pave the way for ultra-secure storage very soon",
#   "summary": "Researchers at Seoul National University have developed Concealable PUF, a new hardware security method that hides encryption keys within commercial 3D NAND flash memory, offering ultra-secure storage without custom hardware. This technique, which uses a weak GIDL erase process to create unique variations, has passed stress tests and resisted machine learning attacks, demonstrating stable concealment and revelation of keys. It promises scalable, cost-effective hardware-level security for devices like IoT, mobile, and automotive electronics.",
#   "keyword": ["Hardware security", "encryption keys", "flash memory", "3D NAND", "Physical Unclonable Functions", "PUFs", "Concealable PUF", "GIDL erase", "data security", "IoT", "mobile electronics", "automotive electronics", "machine learning attacks", "cybersecurity"],
#   "topic": "Cybersecurity",
#   "entities": ["Seoul National University", "Nature Communications", "TechRadar Pro", "Jong-Ho Lee", "Sung-Ho Park", "TechXplore"],
#   "sentiment": "positive"
# },
# {
#   "title": "Amazon Prime users can grab AMD Ryzen 7800X3D and 9600X for lowest prices",
#   "summary": "Amazon Prime members can get AMD Ryzen 7800X3D and 9600X desktop processors at their lowest prices during early Prime Day deals. The Ryzen 9600X, based on Zen 5, is a 6-core/12-thread CPU competing with Intel's i7, while the 7800X3D (Zen 4) remains a top gaming CPU thanks to 3D V-cache. A Ryzen 9 9950X is also available at a discounted price.",
#   "keyword": ["AMD Ryzen", "CPU", "desktop processor", "Zen 5", "Zen 4", "3D V-cache", "gaming CPU", "Amazon Prime Day", "discount", "computer hardware", "sales"],
#   "topic": "Consumer Electronics",
#   "entities": ["Amazon", "AMD Ryzen", "Intel"],
#   "sentiment": "positive"
# },
# {
#   "title": "How a Pro Sports Photographer and Nikon Robotics Revolutionized Ice Hockey Images",
#   "summary": "Swedish sports photographer Joel Marklund, co-owner of Bildbyrån, revolutionized ice hockey photography using remote Nikon robotic cameras at the IIHF World Championship. Overcoming renovation hurdles, Marklund's team deployed Nikon Z9 cameras with MRMC robotic heads, controlled by a PlayStation 5 Dualsense, to capture unique, never-before-seen angles. This innovation, blending competitive photography with advanced technology, aims to be replicated at future events like the 2026 Winter Olympics, showcasing how creativity and tech can elevate sports photojournalism.",
#   "keyword": ["Sports photography", "ice hockey", "robotics", "remote cameras", "Nikon Z9", "MRMC", "PlayStation 5 Dualsense", "AI (implied)", "photojournalism", "visual arts", "technology in sports", "innovation"],
#   "topic": "Photography",
#   "entities": ["Joel Marklund", "Nikon", "Bildbyrån", "International Ice Hockey Federation (IIHF) World Championship", "Avicii Arena", "Stockholm Globe Arena", "Mark Roberts Motion Control (MRMC)", "PlayStation 5", "PetaPixel", "Getty", "Associated Press"],
#   "sentiment": "positive"
# },
# {
#   "title": "Best Amazon Prime Day Hard Drive deals 2025 — internal and external HDD deals from WD, Seagate, and Toshiba",
#   "summary": "The article highlights the best Amazon Prime Day 2025 deals on hard disk drives (HDDs), emphasizing their cost-effectiveness for mass storage. It advises shoppers to consider factors like form factor, SATA interface, and crucially, recording technology (recommending Conventional Magnetic Recording - CMR over Shingled Magnetic Recording - SMR for performance). The Seagate 30TB Exos M is mentioned as the world's largest HDD currently available at a discounted price, primarily for enterprise use.",
#   "keyword": ["Hard disk drive", "HDD", "Amazon Prime Day", "storage", "internal HDD", "external HDD", "CMR", "SMR", "SATA", "RPM", "cache", "data center", "NAS", "Seagate Exos M", "computer hardware", "sales"],
#   "topic": "Computer Hardware",
#   "entities": ["Amazon", "WD", "Seagate", "Toshiba", "Seagate Exos M", "Provantage", "IronWolf Pro", "TechRadar"],
#   "sentiment": "positive"
# },
# {
#   "title": "Lying Witch Noem Tries To Blame Biden For Trump’s Texas Death And Destruction",
#   "summary": "The article criticizes Homeland Security Secretary Kristi Noem for blaming past administrations for \"ancient\" weather technology deficiencies, attempting to deflect responsibility for a lack of flood warnings in Texas, instead of acknowledging the current Trump administration's cuts to the National Weather Service and NOAA. The author accuses Noem and the administration of being \"shameless liars\" whose policies will lead to more deaths, particularly as hurricane season approaches.",
#   "keyword": ["Politics", "natural disaster", "flood", "weather warning", "climate policy", "government funding", "National Weather Service", "NOAA", "political accountability", "misinformation", "Texas floods"],
#   "topic": "Politics",
#   "entities": ["Kristi Noem", "Greg Abbott", "Donald Trump", "Biden", "Texas", "Kerr County", "National Weather Service", "National Oceanic and Atmospheric Administration", "Department of Government Efficiency"],
#   "sentiment": "negative"
# },
# {
#   "title": "Alcon Inc (ALC) Announces Approval of Clareon PanOptix Pro Intraocular Lens",
#   "summary": "Alcon Inc. announced the Canadian approval of its Clareon PanOptix Pro intraocular lens, set to be available by early 2026. This lens features proprietary ENLIGHTEN NXT Optical technology, achieving record-high light utilization (94%) and improving optical image contrast, positioning Alcon as a leader in eye care technology. The approval signifies a positive advancement in vision correction for patients.",
#   "keyword": ["Alcon", "Clareon PanOptix Pro", "intraocular lens", "ENLIGHTEN NXT Optical technology", "vision correction", "eye care", "medical device", "optical technology", "healthcare innovation"],
#   "topic": "Medical Technology",
#   "entities": ["Alcon Inc.", "Canada", "ENLIGHTEN NXT Optical technology"],
#   "sentiment": "positive"
# },
# {
#   "title": "UL-Tech Dash Camera 4K Hidden Front Rear Wi-Fi with 64GB Card $88.18 @ Market Owned via Qubyk Marketplace",
#   "summary": "The UL-Tech Car Dash Camera offers 4K, 170-degree ultra-wide angle recording with dual lenses, clear night vision, and automatic on/off recording, operating day and night using the car battery. Designed to provide hard evidence in road accidents, it also features a 24-hour parking mode sensor, gravity sensor, loop recording, and WDR image processing, supporting up to 128GB MicroSD cards for a worry-free driving experience.",
#   "keyword": ["Dash camera", "4K recording", "Wi-Fi", "car safety", "night vision", "parking mode", "gravity sensor", "loop recording", "WDR image processing", "automotive electronics", "security"],
#   "topic": "Consumer Electronics",
#   "entities": ["UL-Tech", "Qubyk Marketplace"],
#   "sentiment": "positive"
# },
# {
#   "title": "Shure AONIC 50 Premium Wireless Noise Cancelling Headphones (Black) $289 Delivered @ Amazon AU",
#   "summary": "Shure AONIC 50 Premium Wireless Noise Cancelling Headphones are available on Amazon AU for $289, a solid price for the original model despite the Gen 2 update. These headphones feature Bluetooth 5 technology for enhanced stability and range up to 30 feet, offering up to 20 hours of battery life for uninterrupted audio on the go.",
#   "keyword": ["Shure AONIC 50", "noise cancelling headphones", "wireless headphones", "Bluetooth 5", "battery life", "audio technology", "consumer electronics", "sale", "audio equipment"],
#   "topic": "Consumer Electronics",
#   "entities": ["Shure", "Amazon AU", "SoundGuys", "Rtings", "What Hi-Fi"],
#   "sentiment": "positive"
# },
# {
#   "title": "Today in Apple history: Apple ships its last Mac with a CRT monitor",
#   "summary": "On July 5, 2006, Apple discontinued its eMac line, marking the end of the CRT monitor era for Macs after over a quarter-century. This shift to thinner, brighter, and more power-efficient LCD technology, first seen in the iMac G4 in 2002, revolutionized computer design away from bulky \"beige boxes\" and solidified Apple's focus on sleek displays, despite the eMac being a powerful educational machine for its time.",
#   "keyword": ["Apple history", "CRT monitor", "LCD technology", "Mac", "eMac", "iMac G4", "computer design", "display technology", "PowerPC G4", "Radeon 9600", "technological transition"],
#   "topic": "Technology",
#   "entities": ["Apple", "Robert Brunner", "iMac G4"],
#   "sentiment": "neutral"
# },
# {
#   "title": "I keep seeing people at events taking notes on E-Ink tablets — so I tried one to see what all the fuss is about",
#   "summary": "The author explores the appeal of E-Ink tablets for note-taking and productivity, specifically reviewing the BOOX Note Air4 C. These devices offer weeks-long battery life, a paper-like writing experience with a stylus, and minimal distractions due to E-Ink's limitations with color and responsiveness. While the Note Air4 C provides excellent hardware and a customized Android interface for writing and reading, it's not ideal for media consumption, serving best as a dedicated tool for focused work and study.",
#   "keyword": ["E-Ink tablet", "note-taking", "productivity", "e-reader", "BOOX Note Air4 C", "stylus", "Android", "Kaleido 3", "battery life", "digital journaling", "distraction-free"],
#   "topic": "Consumer Electronics",
#   "entities": ["Windows Central", "Zachary Boddy", "ONYX", "BOOX", "HP Amplify 2025", "Consumer Electronics Show 2025", "Amazon Kindle", "Google Play Store", "Microsoft OneDrive", "OneNote", "Daniel Hardcastle"],
#   "sentiment": "positive"
# },
# {
#   "title": "This 4K OLED monitor has stereo speakers that follow you — but it's missing something \"imPORTant\"",
#   "summary": "The Dell S3225QC is a 32-inch 4K QD-OLED monitor with a 120Hz refresh rate, offering excellent display quality and a unique 5-speaker soundbar with AI-powered spatial audio that follows the user. While the display and audio are highly praised, its main drawback is a severe lack of ports (only HDMI 2.1, USB-C video, and two USB-C data ports, lacking DisplayPort or USB-A), making it less suitable as a central hub for multiple devices, despite its premium features and reasonable price.",
#   "keyword": ["OLED monitor", "4K display", "QD-OLED", "spatial audio", "soundbar", "AI", "Dell S3225QC", "display technology", "gaming monitor", "productivity monitor", "ports", "connectivity", "consumer electronics"],
#   "topic": "Consumer Electronics",
#   "entities": ["Dell", "Alienware", "Zachary Boddy", "HP", "Asus", "Windows Central"],
#   "sentiment": "neutral"
# },
# {
#   "title": "Why Microsoft installed a ‘secret’ update on some Windows 10 and 11 PCs",
#   "summary": "Microsoft has quietly \"force-installed\" update KB5001716 on Windows 10 and 11 PCs, primarily to notify users about approaching end-of-support for their Windows versions and to facilitate feature updates. This auxiliary update warns users if their device is nearing or past its support lifecycle or doesn't meet Windows 11 hardware requirements, aiming to encourage transitions to newer, more secure operating systems amidst ongoing free security updates for Windows 10 under specific circumstances.",
#   "keyword": ["Microsoft", "Windows Update", "KB5001716", "Windows 10", "Windows 11", "end of support", "feature update", "security updates", "hardware requirements", "operating system", "software update"],
#   "topic": "Software",
#   "entities": ["Microsoft", "Windows", "Neowin"],
#   "sentiment": "neutral"
# },
# {
#   "title": "Redox gets network booting, work on UNIX domain sockets continues",
#   "summary": "Redox, a Unix-like operating system, continues to advance with recent progress in UNIX domain sockets, a key technology for Wayland support, and the implementation of sendmsg and recvmsg functionality for file descriptor sending. The OS now also supports network booting through PXE for UEFI systems, alongside ongoing fixes in relibc, RedoxFS, various drivers, and updated ports, indicating steady development towards its goals.",
#   "keyword": ["Redox OS", "UNIX domain sockets", "Wayland", "file descriptors", "sendmsg", "recvmsg", "network booting", "PXE", "UEFI", "operating system", "relibc", "RedoxFS", "drivers", "software development"],
#   "topic": "Software Development",
#   "entities": ["Redox", "Ibuki", "Ribbon", "Ron Williams"],
#   "sentiment": "positive"
# },
# {
#   "title": "Why I highly recommend the M4 MacBook Air to most people - especially at $150 off",
#   "summary": "The M4 MacBook Air (13-inch), available at a $150 discount, is highly recommended as a complete package for creativity, productivity, and everyday use. It features an M4 chip, support for two external monitors, a 12MP FaceTime camera with Center Stage, and excellent all-day battery life (over 14 hours). Despite minor drawbacks like only two USB-C ports and a notch, its performance, seamless integration within Apple's ecosystem, and lower starting price make it a strong choice for new Apple laptop users or those upgrading from older devices.",
#   "keyword": ["MacBook Air M4", "Apple laptop", "M4 chip", "external monitors", "Center Stage", "battery life", "productivity", "gaming", "Apple ecosystem", "consumer electronics", "ultrabook", "discount"],
#     "topic": "Consumer Electronics",
#     "entities": ["Apple", "ZDNET", "Amazon", "Bhphotovideo", "Microsoft", "Surface Laptop", "Asus Zenbook A14", "AirPods", "Kyle Kucharski", "Siri"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "UK's Octopus Energy weighs $14 billion demerger of tech arm Kraken, Sky News says",
#     "summary": "UK's Octopus Energy is reportedly considering a £10 billion ($13.7 billion) demerger and stake sale of its technology arm, Kraken Technologies, within the next year. This move, which would involve selling a minority stake to external shareholders and giving existing investors shares in the new independent Kraken business, aims to validate Kraken's valuation and implies a total group valuation of £15 billion or more for Octopus Energy.",
#     "keyword": ["Octopus Energy", "Kraken Technologies", "demerger", "stake sale", "technology arm", "energy industry", "valuation", "business strategy", "investment banking", "corporate finance"],
#     "topic": "Business & Finance",
#     "entities": ["Octopus Energy", "Kraken Technologies", "Sky News", "Reuters"],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "Joining hands for global resilience",
#     "summary": "Prime Minister Datuk Seri Anwar Ibrahim emphasized that developing nations, particularly BRICS and Asean members, are no longer marginal players but possess significant strength in technology, trade, leadership, and morals. He urged for strengthened strategic cooperation and major reforms in global institutions like the UN, IMF, World Bank, and WTO to reflect current realities and needs of developing countries, aiming for a more fair, just, and stable global financial system.",
#     "keyword": ["Global South", "BRICS", "Asean", "developing nations", "strategic cooperation", "multilateralism", "trade", "local currency", "financial system reform", "global institutions", "geopolitics", "economic development"],
#     "topic": "Geopolitics",
#     "entities": ["Datuk Seri Anwar Ibrahim", "BRICS", "Asean", "United Nations", "International Monetary Fund", "World Bank", "World Trade Organisation", "Malaysia", "Luiz Inacio Lula da Silva", "Datuk Mohammad Ali Selamat", "Ambassador Laudemar Goncalves de Aguiar Neto"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Mac Power Users 804: From NeXT to Liquid Glass, with Ken Case",
#     "summary": "This podcast episode features Ken Case, CEO of The Omni Group, discussing his long career in Apple platform development, his tech setup, and his approach to customer communication. The discussion also covers managing applications across software and platform transitions and his thoughts on WWDC.",
#     "keyword": ["Apple platforms", "software development", "The Omni Group", "CEO", "tech setup", "customer communication", "WWDC", "application management", "platform transitions", "podcast"],
#     "topic": "Technology",
#     "entities": ["Ken Case", "The Omni Group", "Stephen", "David", "NeXT", "Liquid Glass", "WWDC", "Apple"],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "You can buy a 30TB hard disk drive, the world's largest HDD right now, for only $618 - Seagate Exos M breaks cover online, and it is a monster",
#     "summary": "Seagate's 30TB Exos M, currently the world's largest HDD, is available online for under $620, making enterprise-grade capacity unexpectedly affordable. This helium-sealed, 3.5-inch Conventional Magnetic Recording (CMR) drive with 7200 RPM and 512MB cache is designed for high-capacity enterprise use cases like hyperscale data centers, boasting a 2.5 million hour MTBF and advanced security features, but is impractical for typical desktop setups.",
#     "keyword": ["Hard disk drive", "HDD", "storage", "Seagate Exos M", "30TB", "enterprise-grade", "data center", "CMR", "helium-sealed", "MTBF", "computer hardware", "pricing", "storage technology"],
#     "topic": "Computer Hardware",
#     "entities": ["Seagate", "ServerSupply", "Provantage", "IronWolf Pro", "TechRadar Pro", "TechXplore"],
#     "sentiment": "positive"
#   },
#   {
#     "title": "Commentary: Whose job is safe from AI?",
#     "summary": "The article, based on Autor and Thompson's framework, explores how AI impacts jobs, suggesting that AI's effect depends on whether it automates high-skilled or low-skilled tasks within a job. It highlights that while AI can enhance creative tasks (like brainstorming for a role-playing game), it might devalue jobs where it automates the \"expert\" component. The author argues that AI could act as a \"secretary, scribe, and editor\" for professions like gardening, impacting different jobs in varied ways.",
#     "keyword": ["AI impact on jobs", "job automation", "skilled labor", "low-skilled labor", "brainstorming", "generative AI", "Luddites", "job safety", "future of work", "task bundling", "labor market"],
#     "topic": "Artificial Intelligence",
#     "entities": ["Autor", "Thompson"],
#     "sentiment": "neutral"
#   },
#   {
#     "title": "London police chief calls for 'mega' forces to cut costs",
#     "summary": "London's Metropolitan Police Commissioner Mark Rowley has proposed merging England and Wales's 43 police forces into 12-15 larger regional entities to cut costs and free up funds for new crime-fighting technology. Rowley argues that current forces are too small and inefficient, hindering their ability to combat modern threats like organized crime and cyberattacks, especially given years of austerity and low public confidence. He also calls for a national policing body and better use of police staff.",
#     "keyword": ["Police reform", "police forces", "cost-cutting", "crime-fighting technology", "Metropolitan Police", "austerity", "organized crime", "cyberattacks", "public confidence", "policing model", "law enforcement"],
#     "topic": "Politics",
#     "entities": ["Mark Rowley", "Metropolitan Police", "England", "Wales", "National Crime Agency", "Germany", "France", "Keir Starmer", "Sarah Everard"],
#     "sentiment": "neutral"
#   }
# ]

# %%
for x in news_collection.find({'relevancy_score': {'$gt': 7}}):
    print('title:',x['title'])
    print( 'news_summary:',x['summary'])
    print('relevance_score',x['relevancy_score'])
    print()
# Out:
# title: Huawei makes bold claim with 3,000 km-range electric car battery
# news_summary: Chinese tech giant Huawei has filed a patent for a solid-state electric vehicle battery claiming an astonishing 3,000 km range and 5-minute charging time, a "holy grail" for the EV sector. While this claim is met with skepticism regarding feasibility and weight, major automakers like BMW, Mercedes-Benz, Toyota, and Stellantis are also actively developing solid-state batteries due to their higher energy density and faster charging capabilities. This development aims to combat "range anxiety" and long charging times, which are significant barriers to EV adoption.
# relevance_score 9
#
# title: HOLY SMOKES! A new, 200% faster DeepSeek R1-0528 variant appears from German lab TNG Technology Consulting GmbH
# news_summary: German firm TNG Technology Consulting GmbH has released DeepSeek-TNG R1T2 Chimera, a new variant of the DeepSeek R1-0528 large language model (LLM) that is significantly faster and more concise, producing answers with less than 40% of the original's output token count while maintaining 90-92% of its reasoning performance. This efficiency gain is achieved through TNG's "Assembly-of-Experts" (AoE) method, which merges weight tensors from multiple pre-trained models. The MIT-licensed model is available on Hugging Face and is highly praised by the AI developer community for its potential to lower inference costs and speed up responses in enterprise applications.
# relevance_score 9
#
# title: Lost in Space: A ‘Game-Changing’ Emissions Satellite Just Went Dark
# news_summary: MethaneSAT, an $88 million satellite backed by Jeff Bezos and the Environmental Defense Fund (EDF) designed to track global methane emissions, went dark after only 15 months in orbit, far short of its five-year intended lifespan. The satellite was crucial for pinpointing industrial methane sources with high precision, and its loss is a major setback for climate efforts, though EDF plans to continue processing existing data and leveraging its algorithms for future missions.
# relevance_score 9
#
# title: Billionaire Mark Cuban Says AI Gives Workers ‘Superpowers,’ but Crypto Is ‘Not Even Close’ to Its iPhone Moment
# news_summary: Mark Cuban believes AI will have a far deeper impact on society than crypto, stating AI gives "superpowers" to employees willing to learn it, transforming jobs by automating binary tasks while rewarding creativity. Conversely, he asserts crypto is "not even close" to its "iPhone moment" due to a lack of mainstream utility, citing issues like meme coins and insufficient collateral requirements in lending. He sees potential for stablecoins in global transactions and and for blockchain in combating deepfakes, but emphasizes the need for better regulation to build trust.
# relevance_score 8
#
# title: Ford CEO Predicts AI Could Eliminate Half of US White-Collar Jobs
# news_summary: Ford CEO Jim Farley predicts that Artificial Intelligence could eliminate half of all white-collar jobs in the U.S. in the coming years. He emphasizes that AI will significantly impact the workforce, leaving many behind.
# relevance_score 9
#
# title: Mark Cuban says AI could make 'just one dude in a basement' the world's first trillionaire
# news_summary: Billionaire Mark Cuban believes that Artificial Intelligence is still in its "preseason" and will eventually create the world's first trillionaire, potentially a single individual skilled in leveraging AI. He compares AI's future ubiquity to computers and smartphones, which faced initial skepticism but became essential, and highlights his own extensive use of AI for both professional and personal tasks.
# relevance_score 8
#
# title: Microsoft reportedly lacks the know-how to fully leverage OpenAI's tech — despite holding IP rights
# news_summary: Reports suggest growing tension in the Microsoft-OpenAI partnership, with Microsoft reportedly struggling to fully leverage OpenAI's technology despite holding IP rights, often needing OpenAI's help to understand it. Issues include Microsoft's alleged reluctance to fund further ChatGPT training (though Altman denies compute constraints), OpenAI's move towards a for-profit entity requiring Microsoft's blessing, and disputes over IP interpretation, especially concerning OpenAI's acquisition of Windsurf, a competitor to Microsoft's GitHub Copilot. This comes amidst a fierce AI talent war, with Meta actively poaching OpenAI researchers.
# relevance_score 8
#
# title: Norway Reached 96.9% Market Share For EVs In June
# news_summary: Norway achieved an unprecedented 96.9% electric vehicle (EV) market share in June 2025, significantly boosted by campaigns offering low-interest rates on new car purchases and an interest rate cut by Norges Bank. The Tesla Model Y alone accounted for over 27% of new car registrations, solidifying EVs' dominant position in the Norwegian market.
# relevance_score 8
#
# title: AI Might Kill Us All (With Carbon Emissions)
# news_summary: The growing demand for AI is causing a significant increase in energy consumption and carbon emissions from data centers, with power usage doubling by 2023 since 2017. The power supplied to these centers is already more carbon-intensive than the U.S. average and is expected to rise further due to increased reliance on fossil fuels for new facilities. Researchers suggest that data centers could reduce their electricity use by half for a few hours during peak loads to help utilities manage demand, but the exact pollution attributable to AI remains unclear due to a lack of transparency.
# relevance_score 9
#
# title: Zuckerberg Was Wrong About the Metaverse. Can We Really Trust Him With Superintelligent AI?
# news_summary: The author questions Mark Zuckerberg's trustworthiness in leading the superintelligent AI era, given his failed metaverse venture where Meta invested billions with little user adoption. Despite Meta's LLaMA models not being groundbreaking, Zuckerberg is aggressively poaching top AI talent with multi-million dollar offers and creating Meta Superintelligence Labs, aiming for "personal superintelligence." The article suggests Zuckerberg is a ruthless competitor buying his way into the next big trend rather than an AI visionary, and his pivot signifies AI's critical importance.
# relevance_score 8
#
# title: ‘There is Going to be Real Pain’ from AI: OpenAI’s Sam Altman Warns ‘There Will Be Whole Categories of Jobs That Go Away’
# news_summary: Sam Altman, CEO of OpenAI, warns that the widespread adoption of AI will cause "real pain" and lead to the disappearance of "whole categories of jobs." This highlights a significant concern about AI's impact on employment.
# relevance_score 9
#
# title: Garmin patents a sensor that can detect dehydration levels and remind you to drink water
# news_summary: Garmin has patented a groundbreaking wearable sensor technology that can accurately measure hematocrit levels (red blood cell proportion in blood) using optical sensors, allowing for precise detection of dehydration. This innovation moves beyond scheduled reminders to provide real-time physiological data, offering revolutionary benefits for endurance athletes and the general public by enabling proactive hydration management and early detection of heat exhaustion, making wearable tech genuinely advanced in preventative health.
# relevance_score 8
#
# title: GitHub CEO says the 'smartest' companies will hire more software engineers — not less — as AI develops
# news_summary: GitHub CEO Thomas Dohmke argues that the "smartest" companies will increase, not decrease, their hiring of software engineers as AI develops, believing AI will enhance individual developer productivity tenfold. He asserts that AI democratizes programming by making it easier to learn, but professional skills will remain crucial for leveraging AI in business. Despite current tech layoffs, Dohmke predicts a future where companies hire more productive developers, as AI expands project backlogs rather than eliminating them.
# relevance_score 8
#
# title: Report: Microsoft's 2025 layoffs revolve around its desperate $80 billion AI infrastructure investment
# news_summary: Microsoft has laid off over 15,000 employees in 2025 across various organizations, reportedly to free up capital for an $80 billion investment in AI infrastructure and technologies. Despite financially strong performance and record profits, the company is cutting headcount, including roles that could be aided by AI, to fund its rapid push into AI, making AI use mandatory for employees, and straining its partnership with OpenAI.
# relevance_score 9
#
# title: NightEagle APT Exploits Microsoft Exchange Flaw to Target China's Military and Tech Sectors
# news_summary: Cybersecurity researchers have identified NightEagle (aka APT-Q-95), a previously undocumented threat actor active since 2023, exploiting a zero-day flaw in Microsoft Exchange servers to target government, defense, and technology sectors in China for intelligence gathering. The group uses a modified Go-based Chisel utility to achieve intranet penetration and has shown a rapid rate of network infrastructure switching. QiAnXin suspects the threat actor is from North America due to operational hours.
# relevance_score 8
#
# title: The Download: AI agents hype, and Google’s electricity plans
# news_summary: Google showcased advanced AI agents capable of complex real-world tasks, raising concerns about potential "hype racing ahead of reality." Concurrently, Google's latest environmental report reveals its data center energy consumption has doubled since 2020, with the company seeking clean electricity solutions like a fusion power plant agreement, highlighting the ballooning energy demands and carbon costs of the AI era. The article also touches on the emergence of "pandemic oracles" like Conor Browne, a biorisk consultant who accurately predicted SARS-CoV-2's broad impact.
# relevance_score 8
#
# title: Scientists just simulated the “impossible” — fault-tolerant quantum code cracked at last
# news_summary: Researchers from Chalmers University of Technology and other institutions have achieved a world-first by developing a method to simulate specific types of error-corrected quantum computations, a long-standing challenge due to the extreme complexity and sensitivity of qubits. Their algorithm can simulate quantum computations using Gottesman-Kitaev-Preskill (GKP) bosonic codes, which are crucial for fault tolerance in quantum computers. This breakthrough, enabled by a new mathematical tool, allows more reliable testing and validation of quantum calculations, paving the way for stable and scalable quantum computers.
# relevance_score 10
#
# title: Record-Breaking Results Bring Fusion Power Closer to Reality
# news_summary: Recent record-breaking achievements in controlled nuclear fusion, particularly at Germany's Wendelstein 7-X stellarator (43 seconds plasma containment) and the UK's Joint European Torus (JET) tokamak (60 seconds), suggest that clean, abundant fusion energy is closer to reality. These breakthroughs in magnetic confinement fusion, alongside inertial confinement successes at the NIF, are fueling optimism, with experts now predicting practical fusion power within 15-20 years, driven by advancements in superconducting magnets and increasing private investment in the field.
# relevance_score 10
#
# title: Ari Aster Says ‘We Have No Say’ in How AI Will Impact the World: It’s ‘Already Too Late’
# news_summary: Horror director Ari Aster expresses profound fear regarding the rise of AI, believing it's "already too late" to control its global impact. He notes that AI engineers often speak of the technology as a "god" rather than a tool, blurring the line between reality and the "imaginal," and he finds AI-generated videos unnervingly realistic. Aster's upcoming film "Eddington" touches on similar themes of alienation and distrust in a world where technology like the internet has become pervasive.
# relevance_score 8
#
# title: Hong Kong scientists 3D printing organs for transplant patients — 3D-printed respiratory tissue combined with lab-grown mini organs in new procedure
# news_summary: Scientists at the University of Hong Kong are 3D printing functional organ tissue for transplants by combining 3D-printed biomaterial with lab-grown organoids (mini-organs) derived from patient stem cells, ensuring genetic compatibility and lower rejection risk. This innovative procedure, currently focused on airway reconstruction, involves embedding organoids into the 3D-printed structure and allows for pre-testing medication allergies, representing a significant advancement in regenerative medicine and personalized transplantation.
# relevance_score 10
#
# title: ‘We Live in a Surveillance State’: Reddit Users Explode Over Reports of ICE’s New Face and Fingerprint Scanning App
# news_summary: Reports reveal that U.S. Immigration and Customs Enforcement (ICE) is deploying "Mobile Fortify," a smartphone app enabling real-time facial recognition and fingerprint scanning in domestic field operations, sparking outrage among Reddit users who view it as a terrifying expansion of the surveillance state. Concerns include the erosion of civil liberties, potential targeting of marginalized communities, and calls for resistance strategies like privacy-enhancing eyewear, highlighting a deep distrust in institutional leadership.
# relevance_score 9
#
# title: China launches first low-inclination orbit SAR satellite 'Haishao-1'
# news_summary: China has launched Haishao-1 (HS-1), its first low-inclination orbit synthetic aperture radar (SAR) satellite, marking a breakthrough in global Earth observation. Operating in a 43° low-inclination orbit at a very low Earth orbit (VLEO) of 350 km, HS-1 significantly enhances spatial resolution and imaging performance, particularly for equatorial and tropical areas, allowing more frequent revisits (up to 5.7 times daily for the South China Sea). Equipped with a dual-sensor system including a nightlight sensor, it provides multi-dimensional views of urbanization, transportation, and maritime activity.
# relevance_score 8
#
# title: Ari Aster Talks “Very Frightening” Future Of AI As Some Treat The Tech “As A God”
# news_summary: Horror director Ari Aster expresses profound fear about the future of AI, stating it's "already too late" to control its evolution, especially as some engineers treat it like a "god," blurring the lines between reality. He finds AI-generated videos unnervingly realistic and warns that human adaptability makes strange things normal over time. Aster's concerns reflect in his film "Eddington," which explores themes of alienation and pervasive technology, emphasizing how people live increasingly within the internet.
# relevance_score 8
#
# title: Gone in 40 days: US drops ban on export of chip design tools to China
# news_summary: The U.S. Bureau of Industry and Security (BIS) has lifted the licensing requirement for exporting Electronic Design Automation (EDA) tools to China, a ban previously introduced by the Trump Administration less than six weeks ago to deny China advanced semiconductor technology for military and economic reasons. While no official reason was given for the reversal, a more congenial tone in recent U.S.-China trade talks is cited as a likely factor, benefiting EDA vendors like Synopsys, Siemens EDA, and Cadence Design Systems.
# relevance_score 8
#
# title: D-Wave and Rigetti: Cantor Chooses the Best Quantum Computing Stocks to Buy
# news_summary: Cantor recommends D-Wave (QBTS) and Rigetti (RGTI) as top quantum computing stocks, both receiving "Strong Buy" ratings. D-Wave, a leader with commercially deployed systems like Advantage2, boasts strong revenue growth and cash position. Rigetti, focusing on advanced QPU architecture and cloud services, is also making progress with its Ankaa-3 system. The sector is in early growth, with valuations based on potential, but these companies are positioned for leadership as commercial applications expand.
# relevance_score 9
#
# title: $88m pollution-tracking satellite missing in space
# news_summary: The $88 million MethaneSat, a pollution-tracking satellite backed by Jeff Bezos and Google, designed to monitor methane emissions from oil and gas production, has been lost in space after only a year in orbit, far short of its five-year mission. This loss is a significant setback for climate efforts, as the satellite's sensitive instruments were crucial for transparently identifying major methane sources, and it is "likely not recoverable."
# relevance_score 9
#
# title: Singapore’s First 3D-Printed Home Is Revolutionizing Multi-Storey Urban Living In The City
# news_summary: Singapore has unveiled QR3D, its first multi-story 3D-printed home by Park + Associates, located in Bukit Timah. This four-story prototype showcases how digital manufacturing can create expressive and functional urban living spaces, with 97% of its grooved, layered concrete walls fabricated on-site by a robotic printer. The design features a sculptural void that channels light and air, reducing the need for internal supports and demonstrating the potential of 3D-printed concrete for structural efficiency and unique architectural forms.
# relevance_score 8
#
# title: OpenAI Hits the Panic Button
# news_summary: OpenAI has given its staff a mandatory week off, seen as a "strategic retreat" amidst an intense talent war, particularly with Meta Platforms aggressively poaching key researchers with "giant offers." CEO Sam Altman attempts to rally employees by emphasizing OpenAI's mission to build AGI for humanity, framing the conflict as "missionaries vs. mercenaries," but also conceded to assessing compensation for the entire research organization, indicating financial pressure. This situation also impacts former OpenAI co-founder Ilya Sutskever's new safety-focused AI lab, Safe Superintelligence (SSI), which has also seen departures due to Meta's poaching.
# relevance_score 9
#
# title: Sweet-smelling molecule halts therapy-resistant pancreatic cancer
# news_summary: Researchers led by Dr. Hideyuki Saya at Fujita Health University have discovered that benzaldehyde, a sweet-smelling compound, can halt therapy-resistant pancreatic cancer. The study, published in the British Journal of Cancer, reveals that benzaldehyde works by preventing the interaction of the signaling protein 14-3-3ζ with histone H3, which is crucial for cancer cell survival, treatment resistance, and metastasis. This finding suggests benzaldehyde's potential as a combinatorial anticancer agent, overcoming resistance to common radiation and tyrosine kinase inhibitor therapies.
# relevance_score 10
#
# title: Deafness reversed: Single injection brings hearing back within weeks
# news_summary: A new study involving Karolinska Institutet and Chinese institutions reports that a single gene therapy injection can improve hearing in children and adults with congenital deafness caused by OTOF gene mutations. All ten patients in the study, aged 1-24, experienced significant hearing improvement within a month, with younger patients showing the best results. The treatment, which delivers a functional OTOF gene to the inner ear via an adeno-associated virus (AAV), was well-tolerated and is a major step forward for genetic deafness treatment, with researchers expanding efforts to other common deafness genes.
# relevance_score 10
